# %%
import matplotlib.pyplot as plt

from HU.app16_fingerprint_plots import (
    plot_2006_fingerprints, plot_2010_fingerprints, 
    plot_2014_fingerprints, plot_2018_fingerprints,  
    plot_2019_fingerprints,
    PARTIES_2006, PARTIES_2010, PARTIES_2014, 
    PARTIES_2018, PARTIES_2019
)

plt.rcParams['figure.figsize'] = [5, 3]

PARTIES_2006
# Out:
# ['FIDESZ-KDNP',
#  'KERESZTÉNYDEMOKRATAPÁRT',
#  'MAGYAR DEMOKRATA FÓRUM',
#  'MIÉP - JOBBIK',
#  'MSZP',
#  'SZDSZ']

# %% [markdown]
# #### Executive summary
#
# It's the capital
#
# #### Less brief
#
# Fidesz performs very differently in the suspicious areas compared to the others.
#
# That they perform quite differently and those areas are more suspicious ... may be explicable, but may be difficult to explain still.
#
# In 2018 the 80% turnout 40% vote share & suspicious "dot" that replaces a less suspicious "line" seems pretty much like a configured one at first.

# %% [markdown]
# # 2006, Budapest

# %%
plot_2006_fingerprints(parties=PARTIES_2006[0:1], save=False, exclude_noncapital=True)
plot_2006_fingerprints(parties=PARTIES_2006[4:5], save=False, exclude_noncapital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>2.82 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>145.8</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>2.79 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>144.0</td></tr>
# </table>

# %% [markdown]
# # 2006, Budapest excl.

# %%
plot_2006_fingerprints(parties=PARTIES_2006[:1], save=False, exclude_capital=True)
plot_2006_fingerprints(parties=PARTIES_2006[4:5], save=False, exclude_capital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.25 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>12.9</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.61 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>31.8</td></tr>
# </table>

# %% [markdown]
# # 2010, Budapest

# %%
plot_2010_fingerprints(PARTIES_2010[:4], save=False, exclude_noncapital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>4.01 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>184.9</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.80 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>36.9</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>1.00 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>46.1</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>1.97 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>91.0</td></tr>
# </table>

# %% [markdown]
# # 2010, Budapest excl.

# %%
plot_2010_fingerprints(PARTIES_2010[:4], save=False, exclude_capital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.13 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-5.8</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.53 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>24.7</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.20 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-9.4</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.05 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>2.2</td></tr>
# </table>

# %% [markdown]
# # 2014, Budapest

# %%
plot_2014_fingerprints(PARTIES_2014, save=False, exclude_noncapital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>3.14 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>154.0</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.84 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>41.4</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.67 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>32.6</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.03 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>1.4</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>2.74 %</td></tr>
# ...

# %% [markdown]
# # 2014, Budapest excl.

# %%
plot_2014_fingerprints(parties=PARTIES_2014, save=False, exclude_capital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.25 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-12.3</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.55 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>27.2</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.12 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-5.8</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.00 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-0.1</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.09 %</td></tr>
# ...

# %% [markdown]
# # 2018 Budapest

# %%
plot_2018_fingerprints(PARTIES_2018, save=False, exclude_noncapital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>2.92 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>159.6</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.91 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>49.7</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.82 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>45.0</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.42 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>23.2</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.60 %</td></tr>
# ...

# %% [markdown]
# # 2018 Budapest excl.

# %%
plot_2018_fingerprints(parties=PARTIES_2018, save=False, exclude_capital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.14 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-7.8</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.40 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>22.0</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.23 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-12.7</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.02 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-1.0</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.07 %</td></tr>
# ...

# %% [markdown]
# # 2019 Budapest

# %%
plot_2019_fingerprints(parties=PARTIES_2019, save=False, exclude_noncapital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>3.72 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>126.2</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.25 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>8.6</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.25 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>8.5</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>1.47 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>49.9</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>1.57 %</td></tr>
# ...

# %% [markdown]
# # 2019 Budapest excl.

# %%
plot_2019_fingerprints(parties=PARTIES_2019, save=False, exclude_capital=True)
# Out:
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.03 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-1.2</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.19 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>6.6</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.04 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-1.4</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>-0.14 %</td></tr>
# <tr><td>Extra votes in difference area (1000s)</td><td>-4.8</td></tr>
# </table>
# <table>
# <tr><th>Statistic</th><th>Value</th>
# <tr><td>Est. percentage points repr. by difference</td><td>0.19 %</td></tr>
# ...
